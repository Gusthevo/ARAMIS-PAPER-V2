# %%
import pandas as pd
import os

df_oral = pd.read_csv("../data/open_review_datasets_improved/iclr_2025_oral.csv")
df_oral
# Out:
#        paper_id                                              title  \
# 0    zl0HLZOJC9  Probabilistic Learning to Defer: Handling Miss...
# 1    zCxGCdzreM  Kinetix: Investigating the Training of General...
# 2    zBbZ2vdLzH  Joint Graph Rewiring and Feature Denoising via...
# 3    z5uVAKwmjf      AFlow: Automating Agentic Workflow Generation
# 4    xyfb9HHvMe  DSPO: Direct Score Preference Optimization for...
# ..          ...                                                ...
# 208  1aF2D2CPHi  Open-Vocabulary Customization from CLIP via Da...
# 209  1HCN4pjTb4  Wide Neural Networks Trained with Weight Decay...
# 210  1CLzLXSFNn  TimeMixer++: A General Time Series Pattern Mac...
# 211  0ctvBgKFgc  ProtComposer: Compositional Protein Structure ...
# 212  07yvxWDSla                    Synthetic continued pretraining
#
#                                                authors       decision  \
# 0     Cuong C. Nguyen, Thanh-Toan Do, Gustavo Carneiro  Accept (Oral)
# ...

# %%
df_sample = df_oral.sample(n=10)
df_sample
# Out:
#        paper_id                                              title  \
# 54   mtJSMcF3ek  Mind the Gap: Examining the Self-Improvement C...
# 50   ny8T8OuNHe  Ctrl-Adapter: An Efficient and Versatile Frame...
# 183  AP0ndQloqR  Geometry of Neural Reinforcement Learning in C...
# 143  N8Oj1XhtYZ  SANA: Efficient High-Resolution Text-to-Image ...
# 53   mtSSFiqW6y  Judge Decoding: Faster Speculative Sampling Re...
# 19   v593OaNePQ    Learning to Search from Demonstration Sequences
# 69   is4nCVkSFA  Can Neural Networks Achieve Optimal Computatio...
# 192  6s5uXNWGIh  MLE-bench: Evaluating Machine Learning Agents ...
# 207  1pXzC30ry5  RMP-SAM: Towards Real-Time Multi-Purpose Segme...
# 49   o2Igqm95SJ          CAX: Cellular Automata Accelerated in JAX
#
#                                                authors       decision  \
# 54   Yuda Song, Hanlin Zhang, Carson Eisenach, Sham...  Accept (Oral)
# 50       Han Lin, Jaemin Cho, Abhay Zala, Mohit Bansal  Accept (Oral)
# ...

# %%
# Caminho completo do arquivo
caminho = "../data/open_review_datasets_to_prompt_tests/iclr_2025_oral_sorted.csv"

# Cria o diretório se não existir
os.makedirs(os.path.dirname(caminho), exist_ok=True)

# Salva o DataFrame no CSV
df_sample.to_csv(caminho, index=False)

# %%
df_poster = pd.read_csv("../data/open_review_datasets_improved/iclr_2025_poster.csv")
df_poster
# Out:
#         paper_id                                              title  \
# 0     zxg6601zoc  Re-Imagining Multimodal Instruction Tuning: A ...
# 1     zxO4WuVGns  Inverse decision-making using neural amortized...
# 2     zvaiz3FjA9    Designing Concise ConvNets with Columnar Stages
# 3     zu7cBTPsDb  MVTokenFlow: High-quality 4D Content Generatio...
# 4     zqzsZ5cXbB  Let the Code LLM Edit Itself When You Edit the...
# ...          ...                                                ...
# 3110  09FiNmvNMw  Divide and Translate: Compositional First-Orde...
# 3111  0823rvTIhs  Weakly-Supervised Affordance Grounding Guided ...
# 3112  03EkqSCKuO  Port-Hamiltonian Architectural Bias for Long-R...
# 3113  02haSpO453  VILA-U: a Unified Foundation Model Integrating...
# 3114  029hDSVoXK  Dynamic Neural Fortresses: An Adaptive Shield ...
#
#                                                 authors         decision  \
# 0     Yiyang Liu, James Chenhao Liang, Ruixiang Tang...  Accept (Poster)
# ...

# %%
df_sample = df_poster.sample(n=10)
df_sample
# Out:
#         paper_id                                              title  \
# 2464  CGhgB8Kz8i  Innovative Thinking, Infinite Humor: Humor Res...
# 917   i8LCUpKvAz  Minimax Optimal Reinforcement Learning with Qu...
# 451   rsZwwjYHuD  Self-Introspective Decoding: Alleviating Hallu...
# 2764  6lB5qtdYAg  HD-Painter: High-Resolution and Prompt-Faithfu...
# 1314  aIMi2lOKIn  Diff3DS: Generating View-Consistent 3D Sketch ...
# 693   meKEKDhdnx  Preble: Efficient Distributed Prompt Schedulin...
# 2504  BUj9VSCoET  Efficient Residual Learning with Mixture-of-Ex...
# 125   xPxHQHDH2u                      Reflective Gaussian Splatting
# 1218  c54apoozCS  On Statistical Rates of Conditional Diffusion ...
# 999   gY08Ou8EL7  LIFe-GoM: Generalizable Human Rendering with L...
#
#                                                 authors         decision  \
# 2464  Han Wang, Yilin Zhao, Dian Li, Xiaohan Wang, s...  Accept (Poster)
# ...

# %%
# Caminho completo do arquivo
caminho = "../data/open_review_datasets_to_prompt_tests/iclr_2025_poster_sorted.csv"

# Cria o diretório se não existir
os.makedirs(os.path.dirname(caminho), exist_ok=True)

# Salva o DataFrame no CSV
df_sample.to_csv(caminho, index=False)

# %%
df_spotlight = pd.read_csv("../data/open_review_datasets_improved/iclr_2025_spotlight.csv")
df_spotlight
# Out:
#        paper_id                                              title  \
# 0    ztzZDzgfrh  ReDeEP: Detecting Hallucination in Retrieval-A...
# 1    z8sxoCYgmd  LOKI: A Comprehensive Synthetic Data Detection...
# 2    ywFOSIT9ik  Revisiting Zeroth-Order Optimization: Minimum-...
# 3    ykuc5q381b  BRIGHT: A Realistic and Challenging Benchmark ...
# 4    yfW1x7uBS5  Adversarial Perturbations Cannot Reliably Prot...
# ..          ...                                                ...
# 375  0fJfVOSUra  ThunderKittens: Simple, Fast, and $\textit{Ado...
# 376  0bmGL4q7vJ  Multi-modal Agent Tuning: Building a VLM-Drive...
# 377  04qx93Viwj  Holistically Evaluating the Environmental Impa...
# 378  03OkC0LKDD  Adaptive Gradient Clipping for Robust Federate...
# 379  00SnKBGTsz  DataEnvGym: Data Generation Agents in Teacher ...
#
#                                                authors            decision  \
# 0    ZhongXiang Sun, Xiaoxue Zang, Kai Zheng, Jun X...  Accept (Spotlight)
# ...

# %%
df_sample = df_spotlight.sample(n=10)
df_sample
# Out:
#        paper_id                                              title  \
# 102  jCPak79Kev  AnalogGenie: A Generative Engine for Automatic...
# 11   xaYlO03tIk  Stem-OB: Generalizable Visual Imitation Learni...
# 25   vVCHWVBsLH  Decomposition Polyhedra of Piecewise Linear Fu...
# 241  MtDd7rWok1             Anti-Exposure Bias in Diffusion Models
# 324  8bjspmAMBk  Quality Measures for Dynamic Graph Generative ...
# 112  hUb2At2DsQ  Rethinking and Improving Autoformalization: To...
# 28   uvHmnahyp1  SynFlowNet: Design of Diverse and Novel Molecu...
# 346  4HRRcqE9SU  ND-SDF: Learning Normal Deflection Fields for ...
# 323  8oCrlOaYcc  Don't flatten, tokenize! Unlocking the key to ...
# 213  R1hIXdST22  Towards General-Purpose Model-Free Reinforceme...
#
#                                                authors            decision  \
# 102      Jian Gao, Weidong Cao, Junyi Yang, Xuan Zhang  Accept (Spotlight)
# 11   Kaizhe Hu, Zihang Rui, Yao He, Yuyao Liu, Pu H...  Accept (Spotlight)
# ...

# %%
# Caminho completo do arquivo
caminho = "../data/open_review_datasets_to_prompt_tests/iclr_2025_spotlight_sorted.csv"

# Cria o diretório se não existir
os.makedirs(os.path.dirname(caminho), exist_ok=True)

# Salva o DataFrame no CSV
df_sample.to_csv(caminho, index=False)

# %%
df_rejected = pd.read_csv("../data/open_review_datasets_improved/iclr_2025_rejected.csv")
df_rejected
# Out:
#         paper_id                                              title  \
# 0     zzR1Uskhj0  High Probability Bounds for Cross-Learning Con...
# 1     zyGrziIVdE          Exploration by Running Away from the Past
# 2     zxqdVo9FjY  Generalization for Least Squares Regression wi...
# 3     zxbQLztmwb  Emergent Symbol-Like Number Variables in Artif...
# 4     zwuemuTiN8  TACD-GRU: Time-Aware Context-Dependent Autoreg...
# ...          ...                                                ...
# 5014  04RGjODVj3  From Rest to Action: Adaptive Weight Generatio...
# 5015  02kZwCo0C3  SAIL: Self-improving Efficient Online Alignmen...
# 5016  02Od16GFRW  Ensembles provably learn equivariance through ...
# 5017  01wMplF8TL  INSTRUCTION-FOLLOWING LLMS FOR TIME SERIES PRE...
# 5018  00ezkB2iZf  MedFuzz: Exploring the Robustness of Large Lan...
#
#                                                 authors decision  \
# 0                         Ruiyuan Huang, Zengfeng Huang   Reject
# ...

# %%
df_sample = df_rejected.sample(n=10)
df_sample
# Out:
#         paper_id                                              title  \
# 4127  BapOwAzicb                HOGT: High-Order Graph Transformers
# 213   xHGL9XqR8Y  The Wisdom of a Crowd of Brains: A Universal B...
# 3358  KadOFOsUpQ  Which Attention Heads Matter for In-Context Le...
# 676   rcdR97P2Mp  Towards continuous machine learning on periodi...
# 4537  634kHJgaOL  ROBO-INSTRUCT: Simulator-Augmented Instruction...
# 2389  WQy61tS53c  Deep Bayesian Filter for Bayes-Faithful Data A...
# 658   rqBc4WnvUP  Multi-view Object-Centric Learning with Identi...
# 2786  RKB4WiesB4  Unsupervised Reinforcement Learning by Maximiz...
# 4785  2fZ9iOVzpR  A Study of Posterior Stability for Time-Series...
# 4539  62DvfHFesc               Longitudinal Latent Diffusion Models
#
#                                                 authors decision  \
# 4127  Xueqi Ma, Xingjun Ma, Chuang Liu, Sarah Monaza...   Reject
# 213   Roman Beliy, navve wasserman, Amit Zalcher, mi...   Reject
# ...

# %%
# Caminho completo do arquivo
caminho = "../data/open_review_datasets_to_prompt_tests/iclr_2025_spotlight_rejected.csv"

# Cria o diretório se não existir
os.makedirs(os.path.dirname(caminho), exist_ok=True)

# Salva o DataFrame no CSV
df_sample.to_csv(caminho, index=False)
